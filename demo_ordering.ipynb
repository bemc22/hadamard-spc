# %%
# %cd "C:\Users\braya\OneDrive\Documents\hadamard-spc"
# Out:
# C:\Users\braya\OneDrive\Documents\hadamard-spc

# %%
from libs import ordering
from libs.ordering import hadamard, sequency, cake_cutting, zig_zag, xy

# %%
import matplotlib.pyplot as plt
sequency.get_index_matrix(4)

plt.imshow(sequency.get_index_matrix(4), cmap='jet', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
sequency.get_index_matrix(16)

plt.imshow(sequency.get_matrix(16), cmap='gray', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
from libs.ordering import get_mask

plt.imshow(get_mask(sequency.get_index_matrix(4), n=4, m=4), cmap='gray', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
i, j = 3, 3

hadamard_matrix = sequency.get_matrix(4)
code = hadamard_matrix[i, :, None] @ hadamard_matrix[j, :, None].T


plt.imshow(code, cmap='gray', interpolation='nearest', vmax=1, vmin=0)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
hadamard_matrix[j, :]
# Out:
# array([ 1, -1,  1, -1])

# %%
ordering.plot(64)

# %%
hadamard.main()
# Out:
# index matrix shape:  (64, 64)
# index matrix dtype:  int32
# index matrix min:  1
# index matrix max:  4096

# %%
sequency.main()
# Out:
# index matrix shape:  (64, 64)
# index matrix dtype:  int32
# index matrix min:  1
# index matrix max:  4096

# %%
cake_cutting.main()
# Out:
# index matrix shape:  (64, 64)
# index matrix dtype:  int32
# index matrix min:  1
# index matrix max:  4096

# %%
zig_zag.main()
# Out:
# index matrix shape:  (64, 64)
# index matrix dtype:  int64
# index matrix min:  1
# index matrix max:  4096

# %%
xy.main()
# Out:
# index matrix shape:  (64, 64)
# index matrix dtype:  int64
# index matrix min:  1
# index matrix max:  4096
